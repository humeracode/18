# %% [markdown]
# <a href="https://colab.research.google.com/github/humeracode/18/blob/main/DSCM21L2A2_My_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Consider you are given this dataset of Diabetes in Indians.**
#
# - We are going to use the Pima Indians onset of diabetes dataset. It describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
# - As such, it is a binary classification problem (onset of diabetes as 1 or not as 0). All of the input variables that describe each patient are numerical.
# - This dataset consists of total of 9 features/columns, including diabetes onset.
#
# #### **Now answer the following questions for the neural network drawn below for this dataset.**

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ### Functions for Questions

# %%
score = 0

# %%
def q1():
  q1 = "What do we call the first layer of this neural network?"
  a1 = input("Enter your answer : ")
  a1 = a1.lower()
  if a1=='input layer':
    s = 1
  else:
    s=0
  return s

# %%
def q2():
  q2 = "How many number of neurons can be there in the first layer of this neural network?"
  a2 = int(input("Enter your answer : "))
  if a2==8:
    s = 1
  else:
    s=0
  return s

# %%
def q3():
  q3 = "How many hidden layers are present in this neural network?"
  a3 = int(input("Enter your answer : "))
  if a3==3:
    s = 1
  else:
    s=0
  return s

# %%
def q4():
  q4 = "There can be any number of neurons in the hidden layer of this neural network. True or False?"
  a4 = input("Enter your answer : ")
  a4 = a4.lower()
  if a4=='true':
    s = 1
  else:
    s=0
  return s

# %%
def q5():
  q5 = "What do we call the last layer of this neural network?"
  a5 = input("Enter your answer : ")
  a5 = a5.lower()
  if a5=='output layer':
    s = 1
  else:
    s=0
  return s

# %%
def q6():
  q6 = "How many number of neurons can be there in the last layer of this neural network?"
  a6 = int(input("Enter your answer : "))
  if a6==1:
    s = 1
  else:
    s=0
  return s

# %% [markdown]
# ### Question 1 - What do we call the first layer of this neural network?

# %%
score += q1()
# Out:
# Enter your answer :

# %% [markdown]
# ### Question 2 - How many number of neurons can be there in the first layer of this neural network?

# %%
score += q2()
# Out:
# Enter your answer : 8

# %% [markdown]
# ### Question 3 - How many hidden layers are present in this neural network?

# %%
score += q3()
# Out:
# Enter your answer : 3

# %% [markdown]
# ### Question 4 - There can be any number of neurons in the hidden layer of this neural network. True or False?

# %%
score += q4()
# Out:
# Enter your answer : true

# %% [markdown]
# ### Question 5 - What do we call the last layer of this neural network?

# %%
score += q5()
# Out:
# Enter your answer : output layer

# %% [markdown]
# ### Question 6 - How many number of neurons can be there in the last layer of this neural network?

# %%
score += q6()
# Out:
# Enter your answer : 1

# %%
print("Your score is :", score)
# Out:
# Your score is : 5
